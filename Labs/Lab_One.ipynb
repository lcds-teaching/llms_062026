# %% [markdown]
# # Python for LLM/NLP Research: General Python Introduction
#
# ## Lab One (Estimated Duration: ~2 hours)
#
# This lab condenses the older Python labs into the core Python skills needed before we start doing NLP in this course. It prepares for the syllabus sequence in the root `README.md`: from basic Python objects, to text handling, to simple NLP workflows for health and social science research.
#
# Guidelines:
# - Use clear variable names.
# - Print intermediate outputs so your reasoning is visible.
# - Do not import external libraries until the final section.
# - If you finish early, complete the stretch tasks.

# %% [markdown]
# ## How to Use This Notebook
#
# - This lab notebook is self-contained; it does not import from or depend on the solution notebook.
# - Run cells from top to bottom.
# - Read the markdown before each code cell; it tells you what the code is trying to do.
# - Use the `Programming Plan` before typing. It breaks the task into small steps.
# - If you get an error, read the last line first, then check whether an earlier cell was skipped.
# - Keep outputs small and inspect them often with `print()`.
# - Do not use confidential health, social care, interview, or institutional data in these exercises.
# - The matching solution notebook has the same structure and can be used after you try the lab.

# %% [markdown]
# ## Part A: Strings, Numbers, and Research Records (Approx. 30 minutes)

# %% [markdown]
# **Why This Matters**
#
# Most NLP and LLM workflows begin with ordinary Python objects: strings, numbers, and variables. In this section, focus less on memorising syntax and more on reading each line carefully. If you can explain what a string contains, what a number represents, and how an output was constructed, you are already doing the kind of inspection needed later for model outputs.

# %% [markdown]
# ### Question 1: Intro String
#
# Print one sentence introducing yourself and one research use of LLMs or NLP that interests you.
#
# Example format:
# `I am Alex and I want to use NLP to study public service feedback.`

# %% [markdown]
# **Programming Plan**
#
# - Put text inside quotation marks.
# - Store each piece of text in a variable.
# - Use an f-string, `f"..."`, when you want Python to insert variable values into a sentence.
# - Print once at the end so you can see the final sentence.

# %%
# Answer 1
name = ""
research_interest = ""

# %% [markdown]
# ### Question 2: Variables and f-strings
#
# Using the variables below, print:
# `Northside | missed appointments | public service feedback | urgent`

# %% [markdown]
# **Programming Plan**
#
# - Keep the provided variables unchanged.
# - Build the output from those variables rather than typing the sentence by hand.
# - Use `|` as ordinary text inside the f-string.
# - Check that the order of values matches the requested output.

# %%
area = "Northside"
topic = "missed appointments"
text_source = "public service feedback"
priority = "urgent"

# %%
# Answer 2

# %% [markdown]
# ### Question 3: Special Characters
#
# Write one line of code that prints exactly this block using `\n` and `\t`:
#
# ```text
# Project: LLMs for research
#     Data: interview notes
#     Task: classify short texts
#     Check: validate outputs
# ```

# %% [markdown]
# **Programming Plan**
#
# - `\n` starts a new line.
# - `\t` inserts a tab.
# - Put the whole block inside one quoted string.
# - Print the string and visually compare it with the target block.

# %%
# Answer 3

# %% [markdown]
# ### Question 4: String Methods
#
# Given:
#
# ```python
# raw_title = "  public service feedback on access to care  "
# raw_label = "URGENT_REFERRAL"
# raw_phrase = "missed_appointment_rate"
# ```
#
# Tasks:
# 1. Strip spaces from `raw_title` and print it in title case.
# 2. Print `raw_label` in lower case.
# 3. Replace `_` with a space in `raw_phrase` and print it.

# %% [markdown]
# **Programming Plan**
#
# - Apply one string method at a time.
# - Use `.strip()` before `.title()` when there may be extra spaces.
# - Use `.lower()` for all-caps labels.
# - Use `.replace(old, new)` when changing underscores into spaces.

# %% [markdown]
# **Before You Code**
#
# String methods are small cleaning tools. They are not neutral: lowercasing, stripping spaces, and replacing characters all change the data. For research work, get into the habit of being able to say exactly what cleaning rule you applied and why.

# %%
raw_title = "  public service feedback on access to care  "
raw_label = "URGENT_REFERRAL"
raw_phrase = "missed_appointment_rate"

# %%
# Answer 4

# %% [markdown]
# ### Question 5: Numbers and Rates
#
# In one small study, `46` of `320` records mention access barriers.
#
# Tasks:
# 1. Compute the access-barrier rate as a decimal.
# 2. Print the rate as a percentage with 1 decimal place.

# %% [markdown]
# **Programming Plan**
#
# - Divide the count by the total to get a decimal rate.
# - Store the result in a clearly named variable.
# - Use an f-string format such as `{rate:.1%}` to print a percentage.
# - Check that the value is plausible before moving on.

# %%
barrier_records = 46
total_records = 320

# %%
# Answer 5

# %% [markdown]
# ## Part B: Lists and Dictionaries (Approx. 35 minutes)

# %% [markdown]
# **Working Pattern**
#
# Lists keep ordered collections. Dictionaries attach names to values. Many real datasets can be understood as a list of dictionaries: each dictionary is one record, and each key is a field. This structure will reappear when we work with API responses, model outputs, and JSON.

# %% [markdown]
# ### Question 6: List Indexing and Slicing
#
# Given:
#
# ```python
# fields = ["record_id", "area", "note_text", "human_label", "model_label", "review_needed"]
# ```
#
# Tasks:
# 1. Print the first item.
# 2. Print the last item using negative indexing.
# 3. Print only the two label fields using a slice.

# %% [markdown]
# **Programming Plan**
#
# - Use index `0` for the first item.
# - Use index `-1` for the last item.
# - Use a slice, `start:stop`, when you want several adjacent items.
# - Remember that the stop position is not included.

# %%
fields = ["record_id", "area", "note_text", "human_label", "model_label", "review_needed"]

# %%
# Answer 6

# %% [markdown]
# ### Question 7: Split a Text Record
#
# Given:
#
# ```python
# record = "Riverside|public respondent missed appointment|access_barrier|review"
# ```
#
# Tasks:
# 1. Split on `|` and print the resulting list.
# 2. Extract and print only the area name.
# 3. Extract and print only the human label.

# %% [markdown]
# **Programming Plan**
#
# - Use `.split("|")` to turn the record string into a list.
# - Print the whole list first so you can inspect the positions.
# - Use indexing to select the area and label.
# - Keep the intermediate list in a variable so later lines are easier to read.

# %%
record = "Riverside|public respondent missed appointment|access_barrier|review"

# %%
# Answer 7

# %% [markdown]
# ### Question 8: Build a Dictionary
#
# Create a dictionary named `case_note` with the following key-value pairs:
# - `record_id`: `"N001"`
# - `area`: `"Central"`
# - `note_text`: `"Caller reports anxiety after rent increase"`
# - `human_label`: `"housing_stress"`
#
# Print each value by querying its key.

# %% [markdown]
# **Programming Plan**
#
# - Use curly braces `{}` for a dictionary.
# - Put keys on the left and values on the right.
# - Query one value at a time with `dictionary_name["key"]`.
# - Print each query so you know the keys are spelled correctly.

# %%
# Answer 8

# %% [markdown]
# ### Question 9: Update and Extend a Dictionary
#
# Starting from:
#
# ```python
# case_note = {"record_id": "N002", "area": "Northside", "human_label": "access_barrier"}
# ```
#
# Tasks:
# 1. Add `note_text` with value `"No transport to clinic this week"`.
# 2. Add `review_needed` with value `True`.
# 3. Print the full dictionary.

# %% [markdown]
# **Programming Plan**
#
# - To add or update a key, use `case_note["new_key"] = value`.
# - Strings need quotation marks; `True` and `False` do not.
# - Print the full dictionary after all changes.
# - Check that no duplicate or misspelled keys were created.

# %%
case_note = {"record_id": "N002", "area": "Northside", "human_label": "access_barrier"}

# %%
# Answer 9

# %% [markdown]
# ### Question 10: List of Dictionaries
#
# Create this list of dictionaries:
#
# ```python
# mini_notes = [
#     {"record_id": "N001", "area": "Central", "human_label": "housing_stress"},
#     {"record_id": "N002", "area": "Northside", "human_label": "access_barrier"},
#     {"record_id": "N003", "area": "Riverside", "human_label": "health_need"}
# ]
# ```
#
# Then print:
# 1. The full second record.
# 2. The area in the third record.
# 3. The label in the first record.

# %% [markdown]
# **Programming Plan**
#
# - Treat `mini_notes` as a list first.
# - Select one record with a list index, for example `mini_notes[1]`.
# - Then select a field from that record with a dictionary key.
# - Read nested access from left to right.

# %%
mini_notes = [
    {"record_id": "N001", "area": "Central", "human_label": "housing_stress"},
    {"record_id": "N002", "area": "Northside", "human_label": "access_barrier"},
    {"record_id": "N003", "area": "Riverside", "human_label": "health_need"},
]

# %%
# Answer 10

# %% [markdown]
# ## Part C: Loops, Conditions, and Functions (Approx. 40 minutes)

# %% [markdown]
# **Working Pattern**
#
# Loops let us repeat the same operation across records. Conditions let us branch when a record meets a rule. Functions let us name a repeated step. These three ideas are enough to build many transparent, auditable text-processing workflows.

# %% [markdown]
# ### Question 11: Loop Through Records
#
# Using `mini_notes`, loop through each record and print:
# `N001 is from Central`
#
# Use the actual `record_id` and `area` values from each dictionary.

# %% [markdown]
# **Programming Plan**
#
# - Start with `for record in mini_notes:`.
# - Inside the loop, use dictionary keys to get `record_id` and `area`.
# - Use an f-string for the printed sentence.
# - Indent the print line so it is inside the loop.

# %%
# Answer 11

# %% [markdown]
# ### Question 12: Conditional Labels
#
# Given:
#
# ```python
# label_counts = {"access_barrier": 7, "housing_stress": 3, "health_need": 5}
# ```
#
# Loop through the dictionary. Print `needs review` if the count is at least 5, otherwise print `lower volume`.

# %% [markdown]
# **Programming Plan**
#
# - Loop through `.items()` to get both the label and its count.
# - Use `if count >= 5:` for the main rule.
# - Use `else:` for the lower-volume case.
# - Print both the label and the decision so the output is interpretable.

# %%
label_counts = {"access_barrier": 7, "housing_stress": 3, "health_need": 5}

# %%
# Answer 12

# %% [markdown]
# ### Question 13: Count Words with a Function
#
# Create a function called `count_words(text)` that:
# 1. Splits the text on whitespace.
# 2. Returns the number of words.
#
# Test it on:
# `"Caller reports anxiety after rent increase"`

# %% [markdown]
# **Programming Plan**
#
# - Define the function with `def count_words(text):`.
# - Inside the function, split the text into words.
# - Return the length of that list.
# - Test the function on the example before using it elsewhere.

# %%
example_note = "Caller reports anxiety after rent increase"

# %%
# Answer 13

# %% [markdown]
# ### Question 14: Clean Text with a Function
#
# Create a function called `clean_label(label)` that:
# - strips surrounding whitespace,
# - converts to lower case,
# - replaces spaces with underscores.
#
# Test it on `" Access Barrier "` and `"Housing Stress"`.

# %% [markdown]
# **Programming Plan**
#
# - Start with a single input variable, `label`.
# - Chain or sequence the cleaning operations.
# - Return the cleaned value rather than printing inside the function.
# - Print test cases after the function definition.

# %%
# Answer 14

# %% [markdown]
# ### Question 15: List Comprehension
#
# Given:
#
# ```python
# raw_labels = ["Access Barrier", "Housing Stress", "Health Need", "Access Barrier"]
# ```
#
# Use a list comprehension and your `clean_label` function to create `clean_labels`.
# Print the result.

# %% [markdown]
# **Programming Plan**
#
# - First think of the ordinary loop: for each label, clean it.
# - Then write the same idea as `[clean_label(label) for label in raw_labels]`.
# - Store the new list in `clean_labels`.
# - Print the list to check every item changed as expected.

# %%
raw_labels = ["Access Barrier", "Housing Stress", "Health Need", "Access Barrier"]

# %%
# Answer 15

# %% [markdown]
# ### Question 16: Error Handling in Data Cleaning
#
# Given:
#
# ```python
# raw_scores = ["4", "2", "missing", "5", "error", "3"]
# ```
#
# Use a loop with `try/except` to:
# 1. Convert valid values to integers and append them to `clean_scores`.
# 2. Skip invalid values with a short printed message.
# 3. Print `clean_scores` at the end.

# %% [markdown]
# **Programming Plan**
#
# - Create an empty list before the loop.
# - In the `try` block, convert the string to an integer and append it.
# - In the `except ValueError` block, print a short skip message.
# - Print the final clean list after the loop ends.

# %% [markdown]
# **Research Note**
#
# Messy data should not silently disappear. When a value cannot be converted, print or log enough information to understand what happened. Later in the course, the same principle applies to failed API calls and surprising model outputs.

# %%
raw_scores = ["4", "2", "missing", "5", "error", "3"]

# %%
# Answer 16

# %% [markdown]
# ## Part D: Files, Tables, and a Mini Workflow (Approx. 35 minutes)

# %% [markdown]
# **Putting It Together**
#
# The final section connects small Python operations into a workflow: write/read data, create a table, add a derived column, and summarize which records need attention. This mirrors the structure of later NLP work, where we often move from raw text to cleaned fields to model-ready tables.

# %%
# File path helper for this notebook.
# This works whether the notebook is opened from the project root,
# from Labs, or from Solutions.
from pathlib import Path

data_dir = Path("Data")
if not data_dir.exists() and Path("../Data").exists():
    data_dir = Path("../Data")

data_dir.mkdir(exist_ok=True)
lab_one_notes_path = data_dir / "lab_one_notes.txt"

print("Lab One notes path:", lab_one_notes_path)
# Out:
# Lab One notes path: ../Data/lab_one_notes.txt

# %% [markdown]
# ### Question 17: Write and Read a Small Text File
#
# Save the following text into `lab_one_notes_path`.
#
# Then read it back and print the number of lines.

# %% [markdown]
# **Programming Plan**
#
# - Use `with open(lab_one_notes_path, "w", ...)` to write the text.
# - Use `with open(lab_one_notes_path, "r", ...)` to read it back.
# - `.readlines()` gives one list item per line.
# - Count that list with `len(...)`.

# %%
mini_report = "Central caller mentions rent increase\nNorthside caller missed clinic visit\nRiverside caller asks for mental health support"

# %%
# Answer 17

# %% [markdown]
# ### Question 18: Build a Small Table
#
# Use plain Python to inspect `mini_notes` as a small table.
#
# Tasks:
# 1. Print each record in `mini_notes`.
# 2. Print the number of rows.
# 3. Print the number of fields in the first row.

# %% [markdown]
# **Programming Plan**
#
# - Treat the table as a list of dictionaries.
# - Print one record per line so the structure is visible.
# - Use `len(notes_table)` for rows.
# - Use `len(notes_table[0])` for the number of fields in the first row.

# %%
# Answer 18

# %% [markdown]
# ### Question 19: Add a Derived Column
#
# Add a field called `review_needed` to each record. It should be `True` when `human_label` is either:
# - `access_barrier`
# - `health_need`
#
# Print `record_id`, `human_label`, and `review_needed` for each record.

# %% [markdown]
# **Programming Plan**
#
# - Make a list of labels that require review.
# - Loop through each record.
# - Add `record["review_needed"] = ...`.
# - Use `in` to test whether the label is in the review list.

# %%
# Answer 19

# %% [markdown]
# ### Question 20: Integrated Mini-Case
#
# Using the objects from this lab, build a short summary table with:
# - `record_id`
# - `area`
# - cleaned `human_label`
# - word count for a note text
# - `review_needed`
#
# Print each summary row. Then print one sentence identifying which records should be reviewed first.

# %% [markdown]
# **Programming Plan**
#
# - Start with an empty `summary_rows` list.
# - Loop through each record with text.
# - Build one new dictionary per record.
# - Append each summary dictionary to the list, then print the results.

# %%
mini_notes_with_text = [
    {"record_id": "N001", "area": "Central", "note_text": "Caller reports anxiety after rent increase", "human_label": "Housing Stress"},
    {"record_id": "N002", "area": "Northside", "note_text": "No transport to clinic this week", "human_label": "Access Barrier"},
    {"record_id": "N003", "area": "Riverside", "note_text": "Needs mental health appointment after discharge", "human_label": "Health Need"},
]

# %%
# Answer 20

# %% [markdown]
# ### Question 21 (Stretch): Debugging and Refactor
#
# This code has multiple problems. Fix it so it prints a correct sentence and uses meaningful variable names:
#
# ```python
# RecordID = "N004"
# word_count = "6"
# print(recordid + " contains " + word_count + 2 + " words")
# ```
#
# After fixing, print:
# `N004 contains 8 words`

# %% [markdown]
# **Programming Plan**
#
# - Read the error-prone code slowly before editing.
# - Fix variable-name consistency first.
# - Convert numeric strings to integers before adding.
# - Use an f-string for the final sentence.

# %%
# Answer 21 (Stretch)
# Broken code to inspect and fix:
# RecordID = "N004"
# word_count = "6"
# print(recordid + " contains " + word_count + 2 + " words")

# Write your corrected version below.

# %% [markdown]
# ## End of Lab Checklist
#
# Before class ends, make sure you have:
# - attempted every core question (1-20),
# - marked any blockers with a short comment,
# - identified one Python concept to review before Lab Two.
