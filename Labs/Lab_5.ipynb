# %% [markdown]
# # Advanced Topics in LLM Implementation
#
# ## Lab Five (Estimated Duration: ~2 hours)
#
# This lab follows the Lecture Five structure in the root `README.md`: multimodal models, LLMs as measurement instruments, LLMs and causal inference, synthetic data and synthetic respondents, agentic systems and tool use, scientific workflows, and open questions.
#
# The lab is implementation-focused but safe to run. It uses mock LLM outputs, public or fallback health/social examples, and plain Python. No API keys, local model servers, image models, or agent frameworks are required.
#
# Rules:
# - Treat LLM outputs as research objects that need validation.
# - Do not use private, personal, health, or confidential data.
# - Keep synthetic examples clearly labelled as synthetic.
# - Log assumptions, prompts, schemas, parameters, and validation checks.

# %% [markdown]
# ## How to Use This Notebook
#
# - This lab notebook is self-contained; it does not import from or depend on the solution notebook.
# - Run cells from top to bottom.
# - Read the markdown before each code cell; it tells you what the code is trying to do.
# - Use the `Programming Plan` before typing. It breaks the task into small steps.
# - If you get an error, read the last line first, then check whether an earlier cell was skipped.
# - Keep outputs small and inspect them often with `print()`.
# - Do not use confidential health, social care, interview, or institutional data in these exercises.
# - The matching solution notebook has the same structure and can be used after you try the lab.

# %% [markdown]
# ## Part A: Multimodal Models and Research Artefacts (Approx. 30 minutes)

# %% [markdown]
# **Why This Matters**
#
# Multimodal LLMs can combine text, images, tables, charts, audio, or documents. In health and social research, that might mean interpreting a public chart, checking a table, or summarising a public report. The implementation challenge is to document what each artefact is and whether it is appropriate to send to a model.

# %% [markdown]
# ### Question 1: Build a Multimodal Artefact Manifest
#
# Create a list describing public research artefacts that might be used in a multimodal workflow.
#
# Include:
# - artefact id,
# - modality,
# - public source,
# - intended task,
# - whether it is safe to send to a remote model.

# %% [markdown]
# **Programming Plan**
#
# - Use one dictionary per artefact.
# - Put the dictionaries into a list.
# - Keep `safe_to_send` as `True` or `False`.
# - Print the records in a readable way.

# %%
# Answer 1

# %% [markdown]
# ### Question 2: Create a Multimodal Request Plan
#
# Build a request plan for asking a model to summarise a public health chart and accompanying text.
#
# Do not upload an image. Use a manifest that describes the inputs you would send.

# %% [markdown]
# **Programming Plan**
#
# - Create a dictionary called `multimodal_request_plan`.
# - Include a text instruction, expected inputs, output format, and safety note.
# - Keep the request focused on public, non-sensitive material.
# - Print the plan.

# %%
# Answer 2

# %% [markdown]
# ### Question 3: Validate Artefact Safety
#
# Write a function that checks whether every artefact in the manifest is safe to send.
#
# Return:
# - `all_safe`,
# - list of artefact ids that need review.

# %% [markdown]
# **Programming Plan**
#
# - Define a function that accepts the manifest list.
# - Start with an empty list called `needs_review`.
# - Loop through artefacts and check `safe_to_send`.
# - Return a small dictionary with the result.

# %%
# Answer 3

# %% [markdown]
# ## Part B: LLMs as Measurement Instruments (Approx. 35 minutes)

# %% [markdown]
# **Why This Matters**
#
# When an LLM classifies, codes, scores, or extracts information, it can become part of a measurement process. That means the output should be treated like a measurement instrument: define the construct, specify the coding rule, compare against human labels, and report uncertainty or error.

# %% [markdown]
# ### Question 4: Define a Coding Rubric
#
# Create a rubric for coding public service feedback into:
# - `access_barrier`,
# - `housing_stress`,
# - `health_need`,
# - `other`.
#
# Each label should have a short definition and one example cue.

# %% [markdown]
# **Programming Plan**
#
# - Use a dictionary where each key is a label.
# - Store each definition as a nested dictionary.
# - Include `definition` and `example_cue`.
# - Print each label and definition.

# %%
# Answer 4

# %% [markdown]
# ### Question 5: Compare Human and LLM Labels
#
# Use the mock labelled examples below. Compare human labels with LLM labels and create a correctness field.

# %%
measurement_examples = [
    {"id": "M001", "text": "Public note mentions bus route changes limiting clinic access.", "human_label": "access_barrier", "llm_label": "access_barrier"},
    {"id": "M002", "text": "Public note mentions rent arrears and risk of eviction.", "human_label": "housing_stress", "llm_label": "housing_stress"},
    {"id": "M003", "text": "Public note asks for support after medication side effects.", "human_label": "health_need", "llm_label": "health_need"},
    {"id": "M004", "text": "Public note describes general satisfaction with local parks.", "human_label": "other", "llm_label": "health_need"},
]

# %% [markdown]
# **Programming Plan**
#
# - Loop through each example.
# - Add `correct = human_label == llm_label`.
# - Count correct examples.
# - Print incorrect examples for inspection.

# %%
# Answer 5

# %% [markdown]
# ### Question 6: Write a Measurement Warning
#
# Write a short dictionary documenting limitations of using the LLM as a measurement instrument.
#
# Include:
# - construct being measured,
# - likely error,
# - validation requirement,
# - reporting rule.

# %% [markdown]
# **Programming Plan**
#
# - Use a dictionary with clear field names.
# - Keep each value as a short sentence.
# - Include at least one human validation step.
# - Print the dictionary.

# %%
# Answer 6

# %% [markdown]
# ## Part C: Causal Inference and Synthetic Data (Approx. 35 minutes)

# %% [markdown]
# **Why This Matters**
#
# LLMs can help organise evidence, generate hypotheses, or extract variables, but they do not make causal claims true. Causal inference still requires design: treatment, outcome, confounders, comparison group, timing, and assumptions.

# %% [markdown]
# ### Question 7: Build a Causal Design Checklist
#
# For the question below, create a checklist with treatment, outcome, confounders, comparison group, timing, and what the LLM can safely help with.
#
# Research question:
#
# `Does improved bus access reduce missed clinic appointments in public service data?`

# %% [markdown]
# **Programming Plan**
#
# - Create a dictionary called `causal_checklist`.
# - Use one key for each design element.
# - Keep the LLM role separate from the causal claim.
# - Print each key-value pair.

# %%
# Answer 7

# %% [markdown]
# ### Question 8: Generate Clearly Synthetic Respondents
#
# Create a small list of synthetic respondents for testing a coding workflow.
#
# Each synthetic record should include:
# - synthetic id,
# - scenario,
# - expected label,
# - disclosure that it is synthetic.

# %% [markdown]
# **Programming Plan**
#
# - Use a list of dictionaries.
# - Make every id start with `SYN_`.
# - Include a `synthetic` field set to `True`.
# - Do not pretend the records are real observations.

# %%
# Answer 8

# %% [markdown]
# ### Question 9: Check Synthetic Data Risks
#
# Write a function that checks synthetic records for basic documentation problems.
#
# Flag records where:
# - `synthetic` is not `True`,
# - disclosure text is missing,
# - expected label is missing.

# %% [markdown]
# **Programming Plan**
#
# - Define a function that accepts records.
# - Loop through each record.
# - Build a list of problems.
# - Return the list and print it.

# %%
# Answer 9

# %% [markdown]
# ## Part D: Agentic Systems, Tools, Workflows, and Open Questions (Approx. 40 minutes)

# %% [markdown]
# **Why This Matters**
#
# Agentic systems combine model calls with tools, memory, retrieval, or multi-step workflows. In research settings, these systems need strict boundaries: what tools can be used, what data can be accessed, what gets logged, and when humans review outputs.

# %% [markdown]
# ### Question 10: Define a Safe Tool Registry
#
# Create a registry of tools an LLM agent might use in a health/social research workflow.
#
# Include:
# - tool name,
# - what it does,
# - allowed input type,
# - risk level,
# - whether human review is required.

# %% [markdown]
# **Programming Plan**
#
# - Use one dictionary per tool.
# - Keep risk levels simple: `low`, `medium`, or `high`.
# - Mark high-risk tools as requiring human review.
# - Print the registry.

# %%
# Answer 10

# %% [markdown]
# ### Question 11: Route a Tool Call Safely
#
# Write a simple router that accepts a requested tool name and returns whether it is allowed.
#
# If the tool is not in the registry, return `allowed=False`.

# %% [markdown]
# **Programming Plan**
#
# - Define a function with inputs `tool_name` and `registry`.
# - Search the registry for the requested tool.
# - Return a decision dictionary.
# - Test one allowed tool and one unknown tool.

# %%
# Answer 11

# %% [markdown]
# ### Question 12: Build a Scientific Workflow Log
#
# Create a workflow log entry for an LLM-assisted coding pipeline.
#
# Include:
# - dataset source,
# - model role,
# - prompt version,
# - validation step,
# - human review step,
# - reproducibility notes.

# %% [markdown]
# **Programming Plan**
#
# - Use a dictionary for the log entry.
# - Include the public dataset source from earlier in the notebook.
# - Keep model role narrow.
# - Print the log entry.

# %%
# Answer 12

# %% [markdown]
# ### Question 13: Final Mini-Case and Open Questions
#
# Design an advanced but realistic LLM research workflow for health or social science.
#
# Include:
# - multimodal or text-only inputs,
# - measurement role,
# - causal claim warning,
# - synthetic data role,
# - tool-use boundary,
# - validation plan,
# - open question for future work.

# %% [markdown]
# **Programming Plan**
#
# - Treat the plan as a one-row table.
# - Use short, explicit fields.
# - Include at least one limitation.
# - Print the plan in a readable way.

# %%
# Answer 13

# %% [markdown]
# ## End of Lab Checklist
#
# Before class ends, make sure you have:
# - designed a multimodal artefact manifest,
# - treated LLM coding as a measurement problem,
# - separated LLM assistance from causal identification,
# - labelled synthetic data clearly,
# - built a safe tool registry,
# - created a reproducible workflow log,
# - named one open question for future research.
